# %%
from elasticsearch import Elasticsearch
import torch

# %%
es = Elasticsearch("http://localhost:9200")

index_name = "  "

mapping = {
    "mappings": {
        "dynamic": "strict",
        "properties": {
            "doc_id": {"type": "keyword"},
            "text": {"type": "text"},
            "embedding": {
                "type": "dense_vector",
                "dims": 384,
                "index": True,
                "similarity": "cosine"
            }
        }
    }
}

# Hapus jika sudah ada
if es.indices.exists(index=index_name):
    es.indices.delete(index=index_name)

es.indices.create(index=index_name, body=mapping)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'doc-index'})

# %%
from sentence_transformers import SentenceTransformer

# Load MiniLM model
model = SentenceTransformer('all-MiniLM-L6-v2')

def get_embedding(text):
    # Langsung encode teks ke dalam bentuk vektor
    embedding = model.encode(text)
    return embedding

# %%
import pandas as pd

dataset = pd.read_csv("quora_dataset.csv")

dataset = dataset.head(10000)

docs = [{"doc_id": str(row["doc_id"]), "text": row["text"]} for _, row in dataset.iterrows()]

docs
# Out:
# [{'doc_id': '1',
#   'text': 'What is the step by step guide to invest in share market in india?'},
#  {'doc_id': '2',
#   'text': 'What is the step by step guide to invest in share market?'},
#  {'doc_id': '3',
#   'text': 'What is the story of Kohinoor (Koh-i-Noor) Diamond?'},
#  {'doc_id': '4',
#   'text': 'What would happen if the Indian government stole the Kohinoor (Koh-i-Noor) diamond back?'},
#  {'doc_id': '5',
#   'text': 'How can I increase the speed of my internet connection while using a VPN?'},
#  {'doc_id': '6',
#   'text': 'How can Internet speed be increased by hacking through DNS?'},
#  {'doc_id': '7', 'text': 'Why am I mentally very lonely? How can I solve it?'},
#  {'doc_id': '8',
#   'text': 'Find the remainder when [math]23^{24}[/math] is divided by 24,23?'},
#  {'doc_id': '9',
#   'text': 'Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?'},
#  {'doc_id': '10', 'text': 'Which fish would survive in salt water?'},
#  {'doc_id': '11',
#   'text': 'Astrology: I am a Capricorn Sun Cap moon and cap rising...what does that say about me?'},
#  {'doc_id': '12',
#   'text': "I'm a triple Capricorn (Sun, Moon and ascendant in Capricorn) What does this say about me?"},
#  {'doc_id': '13', 'text': 'Should I buy tiago?'},
#  {'doc_id': '14',
#   'text': 'What keeps childern active and far from phone and video games?'},
#  {'doc_id': '15', 'text': 'How can I be a good geologist?'},
#  {'doc_id': '16', 'text': 'What should I do to be a great geologist?'},
#  {'doc_id': '17', 'text': 'When do you use シ instead of し?'},
#  {'doc_id': '18', 'text': 'When do you use "&" instead of "and"?'},
#  {'doc_id': '19',
#   'text': 'Motorola (company): Can I hack my Charter Motorolla DCX3400?'},
#  {'doc_id': '20', 'text': 'How do I hack Motorola DCX3400 for free internet?'},
#  {'doc_id': '21',
#   'text': 'Method to find separation of slits using fresnel biprism?'},
#  {'doc_id': '22',
#   'text': 'What are some of the things technicians can tell about the durability and reliability of Laptops and its components?'},
#  {'doc_id': '23', 'text': 'How do I read and find my YouTube comments?'},
#  {'doc_id': '24', 'text': 'How can I see all my Youtube comments?'},
#  {'doc_id': '25', 'text': 'What can make Physics easy to learn?'},
#  {'doc_id': '26', 'text': 'How can you make physics easy to learn?'},
#  {'doc_id': '27', 'text': 'What was your first sexual experience like?'},
#  {'doc_id': '28', 'text': 'What was your first sexual experience?'},
#  {'doc_id': '29',
#   'text': 'What are the laws to change your status from a student visa to a green card in the US, how do they compare to the immigration laws in Canada?'},
#  {'doc_id': '30',
#   'text': 'What are the laws to change your status from a student visa to a green card in the US? How do they compare to the immigration laws in Japan?'},
#  {'doc_id': '31',
#   'text': 'What would a Trump presidency mean for current international master’s students on an F1 visa?'},
#  {'doc_id': '32',
#   'text': 'How will a Trump presidency affect the students presently in US or planning to study in US?'},
#  {'doc_id': '33', 'text': 'What does manipulation mean?'},
#  {'doc_id': '34', 'text': 'What does manipulation means?'},
#  {'doc_id': '35',
#   'text': 'Why do girls want to be friends with the guy they reject?'},
#  {'doc_id': '36', 'text': 'How do guys feel after rejecting a girl?'},
#  {'doc_id': '37',
#   'text': 'Why are so many Quora users posting questions that are readily answered on Google?'},
#  {'doc_id': '38',
#   'text': 'Why do people ask Quora questions which can be answered easily by Google?'},
#  {'doc_id': '39',
#   'text': 'Which is the best digital marketing institution in banglore?'},
#  {'doc_id': '40',
#   'text': 'Which is the best digital marketing institute in Pune?'},
#  {'doc_id': '41', 'text': 'Why do rockets look white?'},
#  {'doc_id': '42', 'text': 'Why are rockets and boosters painted white?'},
#  {'doc_id': '43', 'text': "What's causing someone to be jealous?"},
#  {'doc_id': '44', 'text': 'What can I do to avoid being jealous of someone?'},
#  {'doc_id': '45', 'text': 'What are the questions should not ask on Quora?'},
#  {'doc_id': '47', 'text': 'How much is 30 kV in HP?'},
#  {'doc_id': '48',
#   'text': 'Where can I find a conversion chart for CC to horsepower?'},
#  {'doc_id': '49',
#   'text': 'What does it mean that every time I look at the clock the numbers are the same?'},
#  {'doc_id': '50', 'text': 'How many times a day do a clock’s hands overlap?'},
#  {'doc_id': '51',
#   'text': 'What are some tips on making it through the job interview process at Medicines?'},
#  {'doc_id': '52',
#   'text': 'What are some tips on making it through the job interview process at Foundation Medicine?'},
#  {'doc_id': '53', 'text': 'What is web application?'},
#  {'doc_id': '54', 'text': 'What is the web application framework?'},
#  {'doc_id': '55', 'text': 'Does society place too much importance on sports?'},
#  {'doc_id': '56', 'text': 'How do sports contribute to the society?'},
#  {'doc_id': '57', 'text': 'What is best way to make money online?'},
#  {'doc_id': '58', 'text': 'What is best way to ask for money online?'},
#  {'doc_id': '59', 'text': 'How should I prepare for CA final law?'},
#  {'doc_id': '60',
#   'text': 'How one should know that he/she completely prepare for CA final exam?'},
#  {'doc_id': '61', 'text': "What's one thing you would like to do better?"},
#  {'doc_id': '62', 'text': "What's one thing you do despite knowing better?"},
#  {'doc_id': '63',
#   'text': 'What are some special cares for someone with a nose that gets stuffy during the night?'},
#  {'doc_id': '64',
#   'text': 'How can I keep my nose from getting stuffy at night?'},
#  {'doc_id': '65',
#   'text': 'What Game of Thrones villain would be the most likely to give you mercy?'},
#  {'doc_id': '66',
#   'text': 'What Game of Thrones villain would you most like to be at the mercy of?'},
#  {'doc_id': '67',
#   'text': 'Does the United States government still blacklist (employment, etc.) some United States citizens because their political views?'},
#  {'doc_id': '68',
#   'text': 'How is the average speed of gas molecules determined?'},
#  {'doc_id': '69', 'text': 'What is the best travel website in spain?'},
#  {'doc_id': '70', 'text': 'What is the best travel website?'},
#  {'doc_id': '71',
#   'text': 'Why do some people think Obama will try to take their guns away?'},
#  {'doc_id': '72',
#   'text': 'Has there been a gun control initiative to take away guns people already own?'},
#  {'doc_id': '73',
#   'text': "I'm a 19-year-old. How can I improve my skills or what should I do to become an entrepreneur in the next few years?"},
#  {'doc_id': '74',
#   'text': 'I am a 19 year old guy. How can I become a billionaire in the next 10 years?'},
#  {'doc_id': '75',
#   'text': 'When a girlfriend asks her boyfriend "Why did you choose me? What makes you want to be with me?", what should one reply to her?'},
#  {'doc_id': '76',
#   'text': 'My girlfriend said that we should end this because she is confused about her feelings for me. I wished her well and disconnected. Should I call her and ask her if she wants to get back together?'},
#  {'doc_id': '77', 'text': 'How do we prepare for UPSC?'},
#  {'doc_id': '78', 'text': 'How do I prepare for civil service?'},
#  {'doc_id': '79',
#   'text': 'What is the stall speed and AOA of an f-14 with wings fully swept back?'},
#  {'doc_id': '80',
#   'text': 'Why did aircraft stop using variable-sweep wings, like those on an F-14?'},
#  {'doc_id': '81', 'text': 'Why do Slavs squat?'},
#  {'doc_id': '82', 'text': 'Will squats make my legs thicker?'},
#  {'doc_id': '83', 'text': 'When can I expect my Cognizant confirmation mail?'},
#  {'doc_id': '84', 'text': 'When can I expect Cognizant confirmation mail?'},
#  {'doc_id': '85', 'text': 'Can I make 50,000 a month by day trading?'},
#  {'doc_id': '86', 'text': 'Can I make 30,000 a month by day trading?'},
#  {'doc_id': '87',
#   'text': 'Is being a good kid and not being a rebel worth it in the long run?'},
#  {'doc_id': '88', 'text': 'Is being bored good for a kid?'},
#  {'doc_id': '89',
#   'text': 'What universities does Rexnord recruit new grads from? What majors are they looking for?'},
#  {'doc_id': '90',
#   'text': 'What universities does B&G Foods recruit new grads from? What majors are they looking for?'},
#  {'doc_id': '91',
#   'text': 'What is the quickest way to increase Instagram followers?'},
#  {'doc_id': '92',
#   'text': 'How can we increase our number of Instagram followers?'},
#  {'doc_id': '93',
#   'text': 'How did Darth Vader fought Darth Maul in Star Wars Legends?'},
#  {'doc_id': '94',
#   'text': 'Does Quora have a character limit for profile descriptions?'},
#  {'doc_id': '95',
#   'text': 'What are the stages of breaking up between couple? I mean, what happens after the breaking up emotionally whether its a male or female?'},
#  {'doc_id': '96',
#   'text': 'Who is affected more by a breakup, the boy or the girl?'},
#  {'doc_id': '97',
#   'text': 'What are some examples of products that can be make from crude oil?'},
#  {'doc_id': '98',
#   'text': 'What are some of the products made from crude oil?'},
#  {'doc_id': '99', 'text': 'How do I make friends.'},
#  {'doc_id': '100', 'text': 'How to make friends ?'},
#  {'doc_id': '101',
#   'text': 'Is Career Launcher good for RBI Grade B preparation?'},
#  {'doc_id': '102',
#   'text': 'How is career launcher online program for RBI Grade B?'},
#  {'doc_id': '103',
#   'text': 'Will a Blu Ray play on a regular DVD player? If so, how?'},
#  {'doc_id': '104',
#   'text': 'How can you play a Blu Ray DVD on a regular DVD player?'},
#  {'doc_id': '105', 'text': 'Nd she is always sad?'},
#  {'doc_id': '106',
#   'text': 'Aerodynamically what happens when propellor rotates?'},
#  {'doc_id': '107',
#   'text': "What is the best/most memorable thing you've ever eaten and why?"},
#  {'doc_id': '108',
#   'text': "What is the most delicious dish you've ever eaten and why?"},
#  {'doc_id': '109', 'text': 'How GST affects the CAs and tax officers?'},
#  {'doc_id': '110', 'text': "Why can't I do my homework?"},
#  {'doc_id': '111', 'text': 'How difficult is it get into RSI?'},
#  {'doc_id': '112',
#   'text': "Do you apply for programs like RSI when you're a rising senior?"},
#  {'doc_id': '113', 'text': 'Who is israil friend?'},
#  {'doc_id': '114',
#   'text': 'Is my boyfriend lying about his true feelings for his friend and is he secretly attracted to her?'},
#  {'doc_id': '115', 'text': 'What are some good rap songs to dance to?'},
#  {'doc_id': '116', 'text': 'What are some of the best rap songs?'},
#  {'doc_id': '117',
#   'text': "I was suddenly logged off Gmail. I can't remember my Gmail password and just realized the recovery email is no longer alive. What can I do?"},
#  {'doc_id': '118',
#   'text': "I can't remember my Gmail password or my recovery email. How can I recover my e-mail?"},
#  {'doc_id': '119', 'text': 'What are the best ways to learn French?'},
#  {'doc_id': '120', 'text': 'How do I learn french genders?'},
#  {'doc_id': '121',
#   'text': 'How do I download content from a kickass torrent without registration?'},
#  {'doc_id': '122', 'text': 'Is Kickass Torrents trustworthy?'},
#  {'doc_id': '123',
#   'text': 'Is it normal to have a dark ring around the iris of my eye?'},
#  {'doc_id': '124',
#   'text': 'What causes a dark ring around the iris? How should it be treated?'},
#  {'doc_id': '125',
#   'text': "How is the new Harry Potter book 'Harry Potter and the Cursed Child'?"},
#  {'doc_id': '126', 'text': 'How bad is the new book by J.K Rowling?'},
#  {'doc_id': '127', 'text': 'Why do I always get depressed?'},
#  {'doc_id': '128', 'text': 'Why do I always get depressed in the evening?'},
#  {'doc_id': '129',
#   'text': 'Where can I find a European family office database?'},
#  {'doc_id': '130', 'text': 'Where do I find a U.S. family office database?'},
#  {'doc_id': '131',
#   'text': 'What is Java programming? How To Learn Java Programming Language ?'},
#  {'doc_id': '132', 'text': 'How do I learn a computer language like java?'},
#  {'doc_id': '133', 'text': 'What is the best book ever made?'},
#  {'doc_id': '134',
#   'text': 'What is the most important book you have ever read?'},
#  {'doc_id': '135', 'text': 'Can we ever store energy produced in lightning?'},
#  {'doc_id': '136', 'text': 'Is it possible to store the energy of lightning?'},
#  {'doc_id': '137', 'text': 'What is your review of Performance Testing?'},
#  {'doc_id': '138', 'text': 'What is performance testing?'},
#  {'doc_id': '139',
#   'text': 'At what cost does so much privacy as in Germany come? What else is lost to gain so much privacy?'},
#  {'doc_id': '140',
#   'text': 'Are there any people who genuinely enjoy salad with no dressing?'},
#  {'doc_id': '141', 'text': 'What are the types of immunity?'},
#  {'doc_id': '142',
#   'text': 'What are the different types of immunity in our body?'},
#  {'doc_id': '143', 'text': 'What is a narcissistic personality disorder?'},
#  {'doc_id': '144', 'text': 'What is narcissistic personality disorder?'},
#  {'doc_id': '145', 'text': 'How I can speak English fluently?'},
#  {'doc_id': '146', 'text': 'How can I learn to speak English fluently?'},
#  {'doc_id': '147',
#   'text': "How helpful is QuickBooks' auto data recovery support phone number to recover your corrupted data files?"},
#  {'doc_id': '148',
#   'text': 'What is the quickbooks customer support phone number USA?'},
#  {'doc_id': '149',
#   'text': 'Who is the richest gambler of all time and how can I reach his level?'},
#  {'doc_id': '150',
#   'text': 'Who is the richest gambler of all time and how can I reach his level as a gambler?'},
#  {'doc_id': '151',
#   'text': 'If I fire a bullet backward from an aircraft going faster than the bullet; will the bullet be going backwards?'},
#  {'doc_id': '152',
#   'text': 'Do bullets travel faster than the speed of sound when shot from a gun? If not, is it possible? If they do, what gun and how much devastation occurs?'},
#  {'doc_id': '153', 'text': 'How do I prevent breast cancer?'},
#  {'doc_id': '154', 'text': 'Is breast cancer preventable?'},
#  {'doc_id': '155',
#   'text': "How do I log out of my Gmail account on my friend's phone?"},
#  {'doc_id': '156',
#   'text': 'How can I know who logged in to my Gmail account? (by telling his IP address or device name)?'},
#  {'doc_id': '157', 'text': 'How can I make money through the Internet?'},
#  {'doc_id': '158',
#   'text': 'What are some different ways to make money online, excluding selling things?'},
#  {'doc_id': '159', 'text': 'What is purpose of life?'},
#  {'doc_id': '160',
#   'text': "What's the purpose of life? What is life actually about?"},
#  {'doc_id': '161',
#   'text': "When will the BJP government strip all the Muslims and the Christians of the Indian citizenship and put them on boats like the Rohingya's of Burma?"},
#  {'doc_id': '162',
#   'text': 'Why India does not apply the "Burma-Rohingya model" to deport illegal Bangladeshis?'},
#  {'doc_id': '163',
#   'text': 'What is the right etiquette for wishing a Jehovah Witness happy birthday?'},
#  {'doc_id': '164',
#   'text': 'How important is it to be the first person to wish someone a happy birthday?'},
#  {'doc_id': '165',
#   'text': 'If someone wants to open a commercial FM radio station in any city of India, how much does it cost and what is the procedure?'},
#  {'doc_id': '166',
#   'text': 'I want to make a travel commercial/clip video HD , For India and New Zealand. How much will it cost?'},
#  {'doc_id': '167', 'text': 'Why do Swiss despise Asians?'},
#  {'doc_id': '168',
#   'text': 'Why do technical employees despise sales people so much?'},
#  {'doc_id': '169',
#   'text': 'What are some of the high salary income jobs in the field of biotechnology?'},
#  {'doc_id': '170',
#   'text': 'What are some high paying jobs for a fresher with an M.Tech in biotechnology?'},
#  {'doc_id': '171', 'text': 'How can I increase my height after 21 also?'},
#  {'doc_id': '172', 'text': 'Can height increase after 25?'},
#  {'doc_id': '173',
#   'text': 'What were the major effects of the cambodia earthquake, and how do these effects compare to the Kamchatca earthquakes in 1952?'},
#  {'doc_id': '174',
#   'text': 'What were the major effects of the cambodia earthquake, and how do these effects compare to the Valparaiso earthquake in 1822?'},
#  {'doc_id': '175',
#   'text': 'What is the difference between sincerity and fairness?'},
#  {'doc_id': '176',
#   'text': "What's the difference between honest and sincere?"},
#  {'doc_id': '177', 'text': 'Which is the best gaming laptop under 60k INR?'},
#  {'doc_id': '178', 'text': 'Which is the best gaming laptop under Rs 60000?'},
#  {'doc_id': '179',
#   'text': 'What is your review of The Next Warrior: Proving Grounds - Part 9?'},
#  {'doc_id': '180',
#   'text': 'What is your review of The Next Warrior: Proving Grounds - Part 5?'},
#  {'doc_id': '181',
#   'text': 'What is the best reference book for physics class 11th?'},
#  {'doc_id': '182',
#   'text': 'Which book should I choose for reference for physics and chemistry (class 11, CBSE board)?'},
#  {'doc_id': '183',
#   'text': 'National Institute of Technology, Kurukshetra: How is the social life at NITK, Surathkal?'},
#  {'doc_id': '184',
#   'text': 'National Institute of Technology Karnataka (NITK) , Surathkal: To the graduating batch: What lessons would you want to give to your juniors before you leave?'},
#  {'doc_id': '185',
#   'text': 'What are some of the best romantic movies in English?'},
#  {'doc_id': '186',
#   'text': 'What is the best romantic movie you have ever seen?'},
#  {'doc_id': '188', 'text': 'What causes nightmares that seem real?'},
#  {'doc_id': '189', 'text': 'What is abstract expressionism in painting?'},
#  {'doc_id': '190',
#   'text': 'What are some of the major influences of abstract expressionism?'},
#  {'doc_id': '191', 'text': 'How does 3D printing work?'},
#  {'doc_id': '192', 'text': 'How do 3D printing work?'},
#  {'doc_id': '193',
#   'text': 'What was it like to attend Caltech with Jeremy Ehrhardt?'},
#  {'doc_id': '194', 'text': 'Who are some notable folks who attended Caltech?'},
#  {'doc_id': '195', 'text': 'Why did harry become a horcrux?'},
#  {'doc_id': '196', 'text': 'What is a Horcrux?'},
#  {'doc_id': '197',
#   'text': 'What are the best associate product manager (APM) programs that someone in their early 20s can join to learn product management and have a rewarding career in the company?'},
#  {'doc_id': '198',
#   'text': 'What are the general requirement to become a Product Manager or a Program Manager in a product based software company?'},
#  {'doc_id': '199',
#   'text': 'Why is the number for Skype at 1-855-425-3768 always busy?'},
#  {'doc_id': '200',
#   'text': 'How could I get Skype to work on an android 4.1.1 phone?'},
#  {'doc_id': '201',
#   'text': 'Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?'},
#  {'doc_id': '202',
#   'text': 'Will there be a nuclear war between India and Pakistan?'},
#  {'doc_id': '203',
#   'text': 'Did Ronald Reagan have a mannerism in his speech?'},
#  {'doc_id': '204', 'text': 'How did Ronald Reagan react to 9/11?'},
#  {'doc_id': '205',
#   'text': 'What were the war strategies of the Union and the Confederates during the Civil War?'},
#  {'doc_id': '206',
#   'text': 'How could the Confederates have possibly defeated Union forces at Gettysburg during the American Civil War?'},
#  {'doc_id': '207', 'text': 'Which is the best fiction novel of 2016?'},
#  {'doc_id': '208', 'text': 'Which are some of the best fiction novels?'},
#  {'doc_id': '209', 'text': 'Can I recover my email if I forgot the password?'},
#  {'doc_id': '210', 'text': 'What should I do if I forgot my email password?'},
#  {'doc_id': '211',
#   'text': 'Will the recent demonetisation results in higher GDP? If so how much?'},
#  {'doc_id': '212',
#   'text': 'How demonetisation could affect the GDP of India in both short run and long run?'},
#  {'doc_id': '213', 'text': 'Have you ever heard of travel hacking?'},
#  {'doc_id': '214', 'text': 'Can WhatsApp be hacked?'},
#  {'doc_id': '215', 'text': "What's the difference between love and pity?"},
#  {'doc_id': '216', 'text': 'What is the difference between love and pity?'},
#  {'doc_id': '217',
#   'text': 'How competitive is the hiring process at Republic Bank?'},
#  {'doc_id': '218',
#   'text': 'How competitive is the hiring process at S & T Bank?'},
#  {'doc_id': '219',
#   'text': 'How Google helps in spam ranking adjustment of the search results?'},
#  {'doc_id': '220',
#   'text': 'What is the distribution of traffic between Google organic search results? e.g. #1 vs. #2 in rankings, first page vs. second page'},
#  {'doc_id': '221',
#   'text': 'Where can I watch gonulcelen with english subtitles?'},
#  {'doc_id': '222', 'text': 'Where can I watch sarrainodu with subtitles?'},
#  {'doc_id': '223', 'text': 'Is USA the most powerful country of the world?'},
#  {'doc_id': '224',
#   'text': 'Why is the USA the most powerful country of the world?'},
#  {'doc_id': '225', 'text': 'How do you obtain an instant ulcer pain relief?'},
#  {'doc_id': '226', 'text': 'What is better for a low back pain: heat or ice?'},
#  {'doc_id': '227', 'text': 'What do you think China food?'},
#  {'doc_id': '228', 'text': 'How do you think of Chinese food?'},
#  {'doc_id': '229', 'text': 'What does taking advantage of someone mean?'},
#  {'doc_id': '230',
#   'text': 'Is it worse to take advantage of someone or be materialistic?'},
#  {'doc_id': '231',
#   'text': 'Why do we cry when we are happy and when we are sad?'},
#  {'doc_id': '232', 'text': 'Why do we cry?'},
#  {'doc_id': '233',
#   'text': 'Why do some girls like to stick their their tongues out when taking pictures?'},
#  {'doc_id': '234',
#   'text': 'Why do teen girls (and women in general) allow their boyfriends to take naked pictures of them in this day and (digital) age?'},
#  {'doc_id': '235',
#   'text': 'Did you find the ending of the novel "1984" depressing?'},
#  {'doc_id': '236',
#   'text': 'How do Winston and Julia differ in the novel "1984"? How are they similar?'},
#  {'doc_id': '237',
#   'text': "What are some mind-blowing computer tools that exist that most people don't know about?"},
#  {'doc_id': '238',
#   'text': "What are some mind-blowing technologies that exist that most people don't know about?"},
#  {'doc_id': '239',
#   'text': 'Should the toothbrush be wet or dry before applying the toothpaste?'},
#  {'doc_id': '240', 'text': 'What is the cheapest toothpaste?'},
#  {'doc_id': '241',
#   'text': 'Why my question was marked as needing imrovement?'},
#  {'doc_id': '242',
#   'text': 'How can I ask a question without getting marked as ‘need to improve’?'},
#  {'doc_id': '243',
#   'text': 'What is the difference between a neutral state and a buffer state?'},
#  {'doc_id': '244',
#   'text': 'If every state of the USA declared war against each other, which would win?'},
#  {'doc_id': '245',
#   'text': 'What mineral holds the highest electrical charge?'},
#  {'doc_id': '246',
#   'text': 'What mineral can hold the greatest electrical charge?'},
#  {'doc_id': '247', 'text': 'What is the greatest mystery in the universe?'},
#  {'doc_id': '248', 'text': 'What is the greatest mystery of all time?'},
#  {'doc_id': '249', 'text': 'What is the alternative to machine learning?'},
#  {'doc_id': '250',
#   'text': 'How do I over-sample a multi-class imbalance data set?'},
#  {'doc_id': '251',
#   'text': 'Why does China block sanctions at the UN against the Jaish-e-Mohammad (JeM) chief, Masood Azhar?'},
#  {'doc_id': '252', 'text': 'Why does China support Masood Azhar?'},
#  {'doc_id': '253', 'text': 'What is the mean of future budget?'},
#  {'doc_id': '254', 'text': 'What is the meaning of the future?'},
#  {'doc_id': '255',
#   'text': 'Can excessive amounts of Vitamin C cause me to have a miscarriage?'},
#  {'doc_id': '256', 'text': 'How can Vitamin C cause a miscarriage?'},
#  {'doc_id': '257',
#   'text': 'What is it like to work in Asahi India Glass? What will be the pay scale after one or two years?'},
#  {'doc_id': '258',
#   'text': 'When will we get the Call Letter after we get the Letter of Intent in Asahi India Glass recruitment?'},
#  {'doc_id': '259', 'text': 'How do I access Torbox in India?'},
#  {'doc_id': '260', 'text': 'How do I access Google.com from India?'},
#  {'doc_id': '261', 'text': 'What are some yakshini mantras?'},
#  {'doc_id': '262', 'text': 'What is a Yantra & Mantra?'},
#  {'doc_id': '263', 'text': 'Was six party talks successful?'},
#  {'doc_id': '264', 'text': 'Which course is better in NICMAR?'},
#  {'doc_id': '265', 'text': 'How do I register my domain site email?'},
#  {'doc_id': '266', 'text': 'How do you register a .an domain?'},
#  {'doc_id': '267',
#   'text': 'Is it normal for older men to be attracted to young women?'},
#  {'doc_id': '268', 'text': 'Why am I attracted to older men?'},
#  {'doc_id': '269',
#   'text': 'What is the strongest structure or strongest shape under compression?'},
#  {'doc_id': '270', 'text': 'What is the strongest Kevlar cord?'},
#  {'doc_id': '271', 'text': 'Who are the Rohingya Muslims?'},
#  {'doc_id': '272', 'text': 'Who are the Rohingya people?'},
#  {'doc_id': '274', 'text': 'Does it matter whether humanity is evil or not?'},
#  {'doc_id': '275',
#   'text': 'Are exocytosis and endocytosis examples of active or passive transport?'},
#  {'doc_id': '276', 'text': 'What are examples of passive transport in cells?'},
#  {'doc_id': '277', 'text': 'How i get hair on bald head?'},
#  {'doc_id': '278',
#   'text': 'If I shave my head for 2 years as am getting bald and then grew my hair, will the hair will be same as when I intially have? Or I loose more hair?'},
#  {'doc_id': '279', 'text': 'What is the ideal life after retirement?'},
#  {'doc_id': '280', 'text': "What's life after retirement?"},
#  {'doc_id': '281', 'text': 'What is our stance against Pakistan?'},
#  {'doc_id': '282',
#   'text': 'What is the stance of Pakistan in the possession of weapons of mass destruction by North korea? Does it support DPRK or is it against DPRK?'},
#  {'doc_id': '283', 'text': 'What are good websites for escorts?'},
#  {'doc_id': '284', 'text': 'How do I find a good escort?'},
#  {'doc_id': '285',
#   'text': 'Which one is better polo diesel or grand i10 petrol?'},
#  {'doc_id': '286', 'text': 'What is the best diet for a growing decathlete?'},
#  {'doc_id': '287', 'text': 'Does a black hole have mass?'},
#  {'doc_id': '288', 'text': 'Does a black hole have a finite mass?'},
#  {'doc_id': '289',
#   'text': 'Is Morgan Freeman correct when he says the only way to stop racism, is to stop talking about it?'},
#  {'doc_id': '290',
#   'text': 'What are your views about this Morgan Freeman quote about Racism?'},
#  {'doc_id': '291',
#   'text': 'Does Fab currently offer new employees stock options or RSUs?'},
#  {'doc_id': '292',
#   'text': 'Does Uber currently offer new employees stock options or RSUs?'},
#  {'doc_id': '293', 'text': 'How would you review the site Waveclues?'},
#  {'doc_id': '294', 'text': 'Is there a good pay for reviews site out there?'},
#  {'doc_id': '295',
#   'text': 'In how many ways can we distribute 10 identical looking pencils to 4 students so that each student gets at least one pencil?'},
#  {'doc_id': '296',
#   'text': 'In how many ways 12 apples can be distributed among 4 children such that every child gets at least 2 apples?'},
#  {'doc_id': '297',
#   'text': 'How much would it cost to hire Jerry Seinfeld for 1-2 hours?'},
#  {'doc_id': '298',
#   'text': 'How much on average would it cost to video tape a 2 hour presentation?'},
#  {'doc_id': '299',
#   'text': 'Is 7 days too late for rabies vaccine after a possible non-bite exposure?'},
#  {'doc_id': '300',
#   'text': 'Can I take rabies injection after 1 day of dog bite?'},
#  {'doc_id': '301', 'text': 'How many years Britain ruled India?'},
#  {'doc_id': '302',
#   'text': 'What is the standard amount of time off given for an international relocation?'},
#  {'doc_id': '303', 'text': 'How can I stop being afraid of working?'},
#  {'doc_id': '304', 'text': 'How do you stop being afraid of everything?'},
#  {'doc_id': '305', 'text': 'Why does Red keep the keys in OITNB?'},
#  {'doc_id': '306',
#   'text': 'Why does Red keep the keys in season 4 of Orange is the New Black?'},
#  {'doc_id': '307', 'text': 'At what age should someone lose their virginity?'},
#  {'doc_id': '308',
#   'text': 'At what age, how, and where did you lose your virginity?'},
#  {'doc_id': '309', 'text': 'How forgetful are you?'},
#  {'doc_id': '310', 'text': 'How can I forget my wife?'},
#  {'doc_id': '311', 'text': 'Could Snoke secretly be Darth Maul?'},
#  {'doc_id': '312',
#   'text': 'How could Snoke be Darth Plagueis if he was killed by Emperor Palpatine?'},
#  {'doc_id': '314',
#   'text': 'How do you upload movies on YouTube and monetize them? Is there any issue of copyright'},
#  {'doc_id': '315',
#   'text': 'Would you switch from Canon 6D to Leica D-LUX 109?'},
#  {'doc_id': '316', 'text': 'What tripod should I get for my Canon 6D?'},
#  {'doc_id': '317',
#   'text': 'What does the Quora website look like to members of Quora moderation?'},
#  {'doc_id': '319', 'text': 'Why nobody answer my questions in Quora?'},
#  {'doc_id': '320', 'text': 'Why is no one answering my questions in Quora?'},
#  {'doc_id': '321', 'text': 'What is the funniest joke you know?'},
#  {'doc_id': '322', 'text': 'What is the funniest joke of all time?'},
#  {'doc_id': '323',
#   'text': 'I got job offer @ Chelmsford-Essex, London with £3764 PM pay-after tax deduction. Pls advice tentative monthly expenses for couple? & saving possible?'},
#  {'doc_id': '324',
#   'text': 'If I am leaving Norway, can I pay down my mortgage with my BSU account, and then sell my apartment without having to pay back the tax deduction I got for having BSU?'},
#  {'doc_id': '325', 'text': 'What are stereotypes about the United Kingdom?'},
#  {'doc_id': '326',
#   'text': 'What do Americans think about the United Kingdom?'},
#  {'doc_id': '327', 'text': 'How do I use Twitter as a business source?'},
#  {'doc_id': '328', 'text': 'How can I use Twitter for business?'},
#  {'doc_id': '329',
#   'text': 'How can I transfer money from Skrill to a PayPal account?'},
#  {'doc_id': '330',
#   'text': 'How can I send money from my PayPal account to my Skrill account to withdraw?'},
#  {'doc_id': '331',
#   'text': 'Which is the best earphone with deep bass under 1000?'},
#  {'doc_id': '332', 'text': 'Which is the Best earphones under Rs 1000?'},
#  {'doc_id': '333',
#   'text': 'Are government employees eligible to Sukanya Samrudi Yojana?'},
#  {'doc_id': '334', 'text': 'Can a Government employee apply IEC?'},
#  {'doc_id': '335',
#   'text': "Which is correct - 'Looking forward to speak with you' or 'Look forward to speak with you'?"},
#  {'doc_id': '336', 'text': 'Which is correct: "speak with" or "speak to"?'},
#  {'doc_id': '337', 'text': 'Which are the best engineering fields?'},
#  {'doc_id': '338', 'text': 'What is the best field of engineering?'},
#  {'doc_id': '339',
#   'text': 'How do you make life suit you and stop life from abusing you mentally and emotionally?'},
#  {'doc_id': '340',
#   'text': 'Why are emotionally abusive people in my life? Several ex boyfriends, friends, and past coworkers/bosses have been abusers. Do I attract them?'},
#  {'doc_id': '341',
#   'text': 'What is the difference between gross salary and CTC?'},
#  {'doc_id': '342',
#   'text': 'There seems to be a difference between my weekly paycheck and the yearly salary my employer agreed upon, how does that work?'},
#  {'doc_id': '343', 'text': 'Which are the prospering towns in Kerala?'},
#  {'doc_id': '344', 'text': 'Why are there so many Christians in Kerala?'},
#  {'doc_id': '345', 'text': 'What is the best way to gain confidence?'},
#  {'doc_id': '346',
#   'text': 'How can I speak with more clarity and confidence?'},
#  {'doc_id': '347',
#   'text': 'Does anyone see the relation between Greek gods and Hindu gods?'},
#  {'doc_id': '348',
#   'text': 'What parallelism can we draw between gods of Hindu mythology, Greek mythology, Egyptian mythology, etc.?'},
#  {'doc_id': '349', 'text': 'How do I switch from Apple Music to Spotify?'},
#  {'doc_id': '350', 'text': 'Should I switch from Spotify to Apple Music?'},
#  {'doc_id': '351', 'text': 'Which is the best fixed income fund?'},
#  {'doc_id': '352', 'text': 'What is the best fixed income fund?'},
#  {'doc_id': '353', 'text': 'What is it like to live in Cologne?'},
#  {'doc_id': '354', 'text': 'What is it like to live in Köln, Germany?'},
#  {'doc_id': '355',
#   'text': 'Between Robert De Niro and Al Pacino, who is more successful?'},
#  {'doc_id': '356',
#   'text': 'Who do you regard as the best actor, Robert De Niro or Al Pacino?'},
#  {'doc_id': '357', 'text': 'Why does some people prefer small families.?'},
#  {'doc_id': '358',
#   'text': 'Why do some people prefer to live with small family?'},
#  {'doc_id': '360', 'text': 'Do animals (besides humans) kiss?'},
#  {'doc_id': '361', 'text': 'How do you get deleted Instagram chats?'},
#  {'doc_id': '362', 'text': 'How can I view deleted Instagram dms?'},
#  {'doc_id': '363', 'text': 'How can I stop being addicted to love?'},
#  {'doc_id': '364', 'text': 'How do I stop being addicted to someone?'},
#  {'doc_id': '365',
#   'text': 'What if I hired two private eyes and ordered them to follow each other?'},
#  {'doc_id': '366',
#   'text': 'Would I be able to hire two private investigators and then get them to follow each other?'},
#  {'doc_id': '367', 'text': 'How do I find a startup accelerator?'},
#  {'doc_id': '368',
#   'text': 'How do startup accelerators give you the funding?'},
#  {'doc_id': '369',
#   'text': 'How can I check wifi history and access it through android phones?'},
#  {'doc_id': '370',
#   'text': 'I cannot open Quora through my WiFi router. Why can I only access it through a mobile network?'},
#  {'doc_id': '371',
#   'text': 'What was the significance of the battle of Somme, and how did this battle compare and contrast to the Battle of Rostov?'},
#  {'doc_id': '372',
#   'text': 'What was the significance of the battle of Somme, and how did this battle compare and contrast to the Battle of Riyadh?'},
#  {'doc_id': '373',
#   'text': "What is the most creative college admissions essay you've read?"},
#  {'doc_id': '374',
#   'text': "Has any college admission officer cried in public while reading an applicant's essay?"},
#  {'doc_id': '375',
#   'text': 'What would happen if you cover one of your eyes with an eye patch for one year, then take the patch off?'},
#  {'doc_id': '376', 'text': 'What happens if eye medicine enters the eye?'},
#  {'doc_id': '377',
#   'text': 'Is it possible to pursue many different things in life?'},
#  {'doc_id': '380',
#   'text': 'No fanboys please, but who was the true batman, Christian Bale or Ben Affleck?'},
#  {'doc_id': '381', 'text': 'Which business is good start up in Hyderabad?'},
#  {'doc_id': '382', 'text': 'Which business is better to start in Hyderabad?'},
#  {'doc_id': '383', 'text': 'How can I stop being so possessive?'},
#  {'doc_id': '384',
#   'text': 'How do I stop being over possessive for a person whom I love?'},
#  {'doc_id': '385', 'text': 'Who was the wife of Lord Krishna?'},
#  {'doc_id': '386', 'text': 'Who is the father of lord Krishna?'},
#  {'doc_id': '387',
#   'text': 'What is the best combination of courses I can take up along with CA to enhance my career?'},
#  {'doc_id': '388', 'text': 'What courses must be taken along with CA course?'},
#  {'doc_id': '389', 'text': 'How do you take a screenshot on a Mac laptop?'},
#  {'doc_id': '390',
#   'text': 'How do I take a screenshot on my MacBook Pro? What are some instructions?'},
#  {'doc_id': '391', 'text': 'What is the work of an executive recruiter like?'},
#  {'doc_id': '392',
#   'text': 'What is it like to work with an executive recruiter?'},
#  {'doc_id': '393',
#   'text': "Which psychological need does 'collecting' fulfill?"},
#  {'doc_id': '394', 'text': 'Why do people collect things?'},
#  {'doc_id': '395',
#   'text': 'What are some must watch TV shows before you die?'},
#  {'doc_id': '396', 'text': 'Are there any must watch TV shows?'},
#  {'doc_id': '397', 'text': 'How can I become more fluent in Chinese?'},
#  {'doc_id': '398', 'text': 'How can I become fluent in chinese?'},
#  {'doc_id': '400',
#   'text': 'What will be the impact of scrapping of ₹500 and ₹1000 rupee notes on the real estate market?'},
#  {'doc_id': '401',
#   'text': 'What is the easiest way to become a billionaire($)?'},
#  {'doc_id': '402', 'text': 'What is the best way to become a billionaire?'},
#  {'doc_id': '403',
#   'text': 'Are there People who are willing to give free lectures or conduct free workshop in India colleges?'},
#  {'doc_id': '404',
#   'text': "Almost two weeks in on Prozac, why do I still feel antisocial and still don't want to go to events? Why does my social behavior and mood change daily?"},
#  {'doc_id': '405', 'text': "What's the best way to start learning robotics?"},
#  {'doc_id': '406',
#   'text': 'What is the best way to start robotics? Which is the best development board that I can start working on it?'},
#  {'doc_id': '407', 'text': 'Why do people hate Hillary Clinton?'},
#  {'doc_id': '408',
#   'text': 'What are the reasons that people dislike Hillary Clinton?'},
#  {'doc_id': '409',
#   'text': "Why are women who are on their periods are regarded as 'unclean' such that they are prevented in taking an actived part in rituals (Hinduism)?"},
#  {'doc_id': '410',
#   'text': 'Why is it always expected that a woman should take care of housework, children and cooking (especially in Indian culture)? Are these activities the responsibility of women alone? Why do men not share equally in such work?'},
#  {'doc_id': '411',
#   'text': 'If atheism is the lack of belief in gods, what is the term for the belief that there is no god?'},
#  {'doc_id': '412',
#   'text': 'Is atheism the lack of belief in gods, or a claim that god does not exist?'},
#  {'doc_id': '413', 'text': 'What is it like to be Jack Dorsey?'},
#  {'doc_id': '414', 'text': 'What is Jack Dorsey like?'},
#  {'doc_id': '415',
#   'text': "What are the best quotes/lessons of the Assassin's Creed series?"},
#  {'doc_id': '416',
#   'text': "Which assassin has the best robes in Assassin's Creed?"},
#  {'doc_id': '417',
#   'text': 'Do inkjet printers use color ink when printing black and white documents? If so, why?'},
#  {'doc_id': '418',
#   'text': 'If CMYK printers create black by using colored ink and only complementing with black ink, why do shops charge more for color prints?'},
#  {'doc_id': '419', 'text': 'Why is creativity important?'},
#  {'doc_id': '421',
#   'text': 'If Hillary Clinton could not continue her Presidential campaign how would the Democratic Party choose a new candidate?'},
#  {'doc_id': '422',
#   'text': 'If Hillary Clinton can no longer serve as the Democratic nominee how would her successor be chosen?'},
#  {'doc_id': '423',
#   'text': "How headphones work as an Antenna to play FM radio channels on Mobile phones? Why mobile companies doesn't install the same inbuilt Antenna on phones to be able to play FM without the headphones?"},
#  {'doc_id': '424', 'text': "Why don't phones have a built-in FM antenna?"},
#  {'doc_id': '425',
#   'text': 'What are the best career growth technologies for automation engineers apart from automation tools?'},
#  {'doc_id': '426', 'text': 'Himalayan or Duke KTM 200 for touring?'},
#  {'doc_id': '427',
#   'text': 'What are the disadvantages of listing a company in NSE?'},
#  {'doc_id': '428',
#   'text': 'What are the benefits of listing a company in NSE?'},
#  {'doc_id': '429',
#   'text': "How many derivatives of an object's position with respect to time have to be continuous?"},
#  {'doc_id': '430', 'text': 'When does drawing become fun?'},
#  {'doc_id': '431', 'text': 'Is the neutron star made up of?'},
#  {'doc_id': '432', 'text': 'Is the neutron star made up of only neutrons?'},
#  {'doc_id': '433',
#   'text': 'I got a 3.8 GPA. Is it enough to get into top universities like Harvard?'},
#  {'doc_id': '434',
#   'text': 'Is a 3.8 GPA sufficient to get into a top school?'},
#  {'doc_id': '435',
#   'text': 'What is a profitable way to trade binary options?'},
#  {'doc_id': '436', 'text': 'What is binary options trading?'},
#  {'doc_id': '437', 'text': 'How do I utilize free time to avoid depression?'},
#  {'doc_id': '438',
#   'text': 'Can a person graduating from IIMs like LIK and even the new IIMs like Ranchi and Trichy ever catch up to the graduates from ABC and get a similar package?'},
#  {'doc_id': '439', 'text': 'How can I learn computer security?'},
#  {'doc_id': '440',
#   'text': 'How can I get started to learn information security?'},
#  {'doc_id': '441', 'text': 'How do I earn from Quora?'},
#  {'doc_id': '442', 'text': 'Can I earn money on Quora?'},
#  {'doc_id': '443', 'text': 'What is my puk code?'},
#  {'doc_id': '444', 'text': "What's the PUK for TF64SIMC4?"},
#  {'doc_id': '445', 'text': 'How can I find job in Japan?'},
#  {'doc_id': '446', 'text': 'How can I find an IT job in Japan?'},
#  {'doc_id': '447',
#   'text': 'What are some examples of sentences using the word "hysteria"?'},
#  {'doc_id': '448',
#   'text': 'What is the best home wireless network setup and expected speeds?'},
#  {'doc_id': '449',
#   'text': 'Will there be another billion dollar lottery Jackpot?'},
#  {'doc_id': '450',
#   'text': 'When will the lottery reach the next billion dollar jackpot?'},
#  {'doc_id': '451',
#   'text': 'How scary is it to drive on the road to Hana given all of the turns?'},
#  {'doc_id': '452',
#   'text': 'Do I need a four-wheel-drive car to drive all the way on the Road to Hana?'},
#  {'doc_id': '453',
#   'text': 'How do I create a new shell in a new terminal using C programming (Linux terminal)?'},
#  {'doc_id': '454',
#   'text': 'How do I create a new Terminal and new shell in Linux using C programming?'},
#  {'doc_id': '455', 'text': 'Does cognition affect perception?'},
#  {'doc_id': '456', 'text': 'Does cognitive strain affect digestion?'},
#  {'doc_id': '457',
#   'text': 'How TQWL is different from CKWL (Tatkal waiting list)?'},
#  {'doc_id': '458',
#   'text': 'I have made a railway reservation but got it on the Tatkal waiting list. Will I get a refund if I cancel it?'},
#  {'doc_id': '459',
#   'text': 'How can we make the world a better place to live in for the future generations?'},
#  {'doc_id': '460', 'text': 'What can I do to make the world a better place?'},
#  {'doc_id': '461',
#   'text': 'How many Champions are there in League of Legends?'},
#  {'doc_id': '462',
#   'text': 'Who is the best LoL (League of Legends) champion?'},
#  {'doc_id': '463',
#   'text': 'Is drinking 4 liters of water each day unhealthy?'},
#  {'doc_id': '464',
#   'text': 'How many liters of water should I drink if I run 5kms daily?'},
#  {'doc_id': '465',
#   'text': 'Where does the water from the Great Lakes come from, and how does these lakes wildlife compare to Lake Prespa?'},
#  {'doc_id': '466',
#   'text': 'Where does the water from the Great Lakes come from, and how does these lakes wildlife compare to Lake Como?'},
#  {'doc_id': '467', 'text': 'Do porn stars watch porn?'},
#  {'doc_id': '468',
#   'text': 'How can I book Ronda Rousey to star in an adult movie?'},
#  {'doc_id': '469',
#   'text': "Trump supporters, how do you feel about the way he's walking back his promises?"},
#  {'doc_id': '470',
#   'text': 'Do Trump supporters now expect the president to live up to his promises he so forcefully sold them on?'},
#  {'doc_id': '471', 'text': "Why are we worried about others' opinions?"},
#  {'doc_id': '472',
#   'text': "Why do we care for others' opinion and about what others think about us?"},
#  {'doc_id': '473', 'text': 'How do you potty train a 4 months Pitbull?'},
#  {'doc_id': '474',
#   'text': 'How do I potty train my two-month-old Labrador pup?'},
#  {'doc_id': '475',
#   'text': 'If I jump rope for five minutes, how many calories will I use?'},
#  {'doc_id': '476', 'text': "What's the best way to jump rope?"},
#  {'doc_id': '477',
#   'text': 'Which online test series is best for GATE 2017 in CS stream?'},
#  {'doc_id': '478',
#   'text': 'Which test series is the best for GATE computer science stream?'},
#  {'doc_id': '479',
#   'text': 'What is the best material for understanding algorithmic analysis by a newbie?'},
#  {'doc_id': '480',
#   'text': 'What math does a complete newbie need to understand algorithms for computer programming? What books on algorithms are suitable for a complete beginner?'},
#  {'doc_id': '481',
#   'text': 'What is the temperament of a Bullmastiff/Husky mix?'},
#  {'doc_id': '482', 'text': 'What is the temperament of a Corgi-Husky mix?'},
#  {'doc_id': '483',
#   'text': "There are 8 balls. 7 of them weigh the same. 1 of them has a different weight, (you don't know if it's heavier or lighter). How do you find the odd ball with 2 weighs?"},
#  {'doc_id': '484',
#   'text': 'How many 4 digit numbers can be formed by using 0, 1, 2, 3, 4, 5, 6, and 7? How many of them are between 4000 and 6000?'},
#  {'doc_id': '485',
#   'text': 'In the play "A Raisin in the Sun", why do Walter ad Beneatha argue?'},
#  {'doc_id': '486',
#   'text': 'In "A Raisin in the Sun", why do Walter and Beneatha argue?'},
#  {'doc_id': '487',
#   'text': 'What are the signs of an ultra smart person playing dumb?'},
#  {'doc_id': '488',
#   'text': 'What are signs of ultra smart people hiding their intelligence?'},
#  {'doc_id': '489',
#   'text': 'If dark energy is created with expansion can infinite of it be created?'},
#  {'doc_id': '490',
#   'text': 'If energy is not conserved in an expanding universe, is potential energy infinite (the energy that can be created is infinite)?'},
#  {'doc_id': '491', 'text': 'How do you get a book published?'},
#  {'doc_id': '492',
#   'text': 'What are the good ways to write and publish a book?'},
#  {'doc_id': '494', 'text': 'Who will disrupt Bloomberg?'},
#  {'doc_id': '495', 'text': 'Why can flash run so fast?'},
#  {'doc_id': '496',
#   'text': 'The Flash (DC character): How fast can the Flash run a mile?'},
#  {'doc_id': '497',
#   'text': 'What is the best way to invest $500 legally so that I can get tangible profits over a relatively short period of time, say 6 months?'},
#  {'doc_id': '498',
#   'text': 'How can I best invest ₹5000 over the next 6 months?'},
#  {'doc_id': '499',
#   'text': 'How will the implementation of GST bill impact the lives of common people?'},
#  {'doc_id': '500',
#   'text': 'What exactly is GST bill and how exactly will it affect the common people?'},
#  {'doc_id': '501', 'text': 'How can you recover your Gmail password?'},
#  {'doc_id': '502',
#   'text': 'I do not remember my password to my Gmail account, how can I recover my account?'},
#  {'doc_id': '503',
#   'text': 'How accurately can a mental illness can be diagnosed?'},
#  {'doc_id': '504',
#   'text': 'How can I accurately diagnose and medicate my mental illness?'},
#  {'doc_id': '505', 'text': 'Is knee pain in a 20 year old girl normal?'},
#  {'doc_id': '506',
#   'text': 'Is it normal for a 14 year old girl to be spitting up blood?'},
#  {'doc_id': '507', 'text': 'What are the qualities of a good leader?'},
#  {'doc_id': '508', 'text': 'What are some good qualities of a leader?'},
#  {'doc_id': '509',
#   'text': 'What is the difference between bay, gulf and straits?'},
#  {'doc_id': '510',
#   'text': 'What exactly is the difference between a sea and a bay?'},
#  {'doc_id': '511', 'text': 'Will Modi win in 2019?'},
#  {'doc_id': '512',
#   'text': 'Can Narendra Modi become Prime Minister of India in 2019?'},
#  {'doc_id': '513',
#   'text': 'How can I open DMart store in India? Is there any franchise for that?'},
#  {'doc_id': '514', 'text': 'How do I get reliance digital store franchise?'},
#  {'doc_id': '515',
#   'text': 'What are the best YouTube channels to learn medicine?'},
#  {'doc_id': '516',
#   'text': 'What are some of the best YouTube channels for learning Git?'},
#  {'doc_id': '517',
#   'text': 'Did Swami Vivekananda ever eat non-veg or egg during his journey around the world?'},
#  {'doc_id': '518', 'text': "Why don't most of the Hindus eat non-veg?"},
#  {'doc_id': '519',
#   'text': 'What will happen if I cancel TQWL tickets before the charting is done?'},
#  {'doc_id': '520', 'text': "Can we cancel a 'Tatkal waiting list' ticket?"},
#  {'doc_id': '521',
#   'text': 'What exactly is the "Common Core Initiative/Standards" and what are the pros and cons?'},
#  {'doc_id': '522',
#   'text': 'What are the pros and cons of the Common Core Standards Initiative?'},
#  {'doc_id': '523', 'text': 'How do I choose a journal to publish my paper?'},
#  {'doc_id': '524', 'text': 'Where do I publish my paper?'},
#  {'doc_id': '525', 'text': "What are your New Year's resolutions for 2017?"},
#  {'doc_id': '526',
#   'text': "What is your creative New Year's resolution for 2017?"},
#  {'doc_id': '527', 'text': 'What do you do if you had a bad dream?'},
# ...
#  {'doc_id': '845',
#   'text': 'Which car services are available in Atlanta? How good are they compared to taxis and relative to each other?'},
#  {'doc_id': '846',
#   'text': 'Why can’t charged molecules pass through the lipid cell membrane?'},
#  {'doc_id': '847',
#   'text': "Why can't sodium channels pass through potassium channels?"},
#  {'doc_id': '848',
#   'text': 'How does it feel to be a spouse of a renowned porn star?'},
#  {'doc_id': '849',
#   'text': 'How can I get rid of the feeling that my spouse is cheating on me?'},
#  {'doc_id': '850',
#   'text': 'What is the best hostel booking affiliate program?'},
#  {'doc_id': '851', 'text': 'Which is the best non AC girls hostel in Srm?'},
#  {'doc_id': '852',
#   'text': "How can the drive from Brooklyn to Staten Island be described, and how do these cities' tourist attractions compare to those in Queens?"},
#  {'doc_id': '853',
#   'text': "How can the drive from Brooklyn to Staten Island be described, and how do these cities' tourist attractions compare to other tourist attractions?"},
#  {'doc_id': '854', 'text': 'What can I eat every day to be more healthy?'},
#  {'doc_id': '855', 'text': 'Is it healthy to eat a whole avocado every day?'},
#  {'doc_id': '856',
#   'text': 'How do I make free calls to family members on Airtel Andhra Pradesh?'},
#  {'doc_id': '857',
#   'text': 'How do I get Facebook badge notifications on HTC 10?'},
#  {'doc_id': '859', 'text': 'What will Hillary Clinton do now?'},
#  {'doc_id': '860', 'text': 'Should I use Vicks Vapor Rub for a stuffy nose?'},
#  {'doc_id': '861',
#   'text': 'How do you apply Vicks Vapor rub to treat a stuffy nose?'},
#  {'doc_id': '862',
#   'text': 'How I start prepare for UGC net English literature latest syllabus?'},
#  {'doc_id': '863',
#   'text': 'How do I prepare for Net JRF in English literature?'},
#  {'doc_id': '864',
#   'text': 'How did early Europeans get protein before the Columbian Exchange?'},
#  {'doc_id': '865',
#   'text': 'How did they say breakfast in Portuguese before coffee was introduced to Europeans & the Portuguese language?'},
#  {'doc_id': '866', 'text': 'What is the best forum for graphic designers?'},
#  {'doc_id': '867', 'text': 'Who is the best graphic designer in israel?'},
#  {'doc_id': '868', 'text': 'Is Alex Jones a satirical show?'},
#  {'doc_id': '869', 'text': 'How is The Canterbury Tales a satire?'},
#  {'doc_id': '870',
#   'text': "Should I learn AngularJS 1.5 instead of AngularJS 2 if I don't know TypeScript?"},
#  {'doc_id': '871',
#   'text': 'Which should I start with: Angular 2 or AngularJS 1?'},
#  {'doc_id': '872', 'text': "Why can't we fall asleep on some days?"},
#  {'doc_id': '873', 'text': 'Why do we fall asleep?'},
#  {'doc_id': '874',
#   'text': 'Which Marvel movies have not included Stan Lee cameos?'},
#  {'doc_id': '875',
#   'text': 'What is your favourite Stan Lee cameo in a Marvel film?'},
#  {'doc_id': '876',
#   'text': 'What are your views on Modi governments decision to demonetize 500 and 1000 rupee notes? How will this affect economy?'},
#  {'doc_id': '877',
#   'text': 'What are your views on ban of 500 and 1000 rupee notes in India?'},
#  {'doc_id': '878',
#   'text': "What does the 10/6 label on the Mad Hatter's hat mean?"},
#  {'doc_id': '879',
#   'text': 'How do you find a figure labeled this way in a textbook?'},
#  {'doc_id': '880', 'text': 'Who wrote the Kars for Kids jingle?'},
#  {'doc_id': '881',
#   'text': 'I am a freelance musician. How can I get into the jingle industry?'},
#  {'doc_id': '882', 'text': 'Why is Saltwater Taffy candy imported in Greece?'},
#  {'doc_id': '883', 'text': 'Why is Saltwater taffy candy imported in China?'},
#  {'doc_id': '884', 'text': 'What are the minimum requirements to enter MIT?'},
#  {'doc_id': '886', 'text': 'How do you answer a question on Quora?'},
#  {'doc_id': '887',
#   'text': "What is the best thing you've ever learned on Quora?"},
#  {'doc_id': '888', 'text': 'Israel vs Iran: who would win?'},
#  {'doc_id': '889', 'text': 'If Israel and Iran went to war, who would win?'},
#  {'doc_id': '890', 'text': 'When is it too late to learn the piano?'},
#  {'doc_id': '891',
#   'text': "I'm almost 40. Is it too late for me to learn piano?"},
#  {'doc_id': '892', 'text': 'What are natural numbers?'},
#  {'doc_id': '893', 'text': 'What is a least natural number?'},
#  {'doc_id': '894', 'text': 'Is One Plus 3T 4G VoLTE enabled phone?'},
#  {'doc_id': '895', 'text': 'Which phone to buy Moto m or one plus 3t?'},
#  {'doc_id': '896',
#   'text': 'How do I enter a new email ID which I can access to recover my Facebook ID?'},
#  {'doc_id': '897',
#   'text': "I lost all my ID. I am adopted and can't access my original birth certificate. How do I replace my ID without even a birth certificate?"},
#  {'doc_id': '898', 'text': 'How we can travel faster than light?'},
#  {'doc_id': '899', 'text': 'Is it possible to travel faster than light?'},
#  {'doc_id': '900', 'text': 'What is it like being a firefighter?'},
#  {'doc_id': '901', 'text': "What's it like to be a firefighter?"},
#  {'doc_id': '902',
#   'text': 'What are the factors that causes data inconsistency in distributed platform/application?'},
#  {'doc_id': '903', 'text': 'What are the main data platform?'},
#  {'doc_id': '904',
#   'text': 'What are the differences between POCSO and sexual offenses in the IPC?'},
#  {'doc_id': '905', 'text': 'Do we need the IPC section 375?'},
#  {'doc_id': '906', 'text': 'What is an alternative for the word "is"?'},
#  {'doc_id': '907', 'text': 'What is the alternative word for creative?'},
#  {'doc_id': '908', 'text': 'What is considered an illegal screen in the NBA?'},
#  {'doc_id': '909',
#   'text': "Shaquille O'Neal considers Tim Duncan a power forward therefore disqualifying Duncan from the NBA great big men discussion. Does O'Neal have a point?"},
#  {'doc_id': '910',
#   'text': 'Nothing excites me anymore. How do I regain that excitement?'},
#  {'doc_id': '911',
#   'text': "Why do I feel like I'm excited about something when I have nothing to be excited about?"},
#  {'doc_id': '912',
#   'text': 'What are the life lessons that Batman teaches us?'},
#  {'doc_id': '913',
#   'text': 'What are the life lessons you can learn from the dark knight?'},
#  {'doc_id': '914',
#   'text': "How do you stop a criminal's attempt to kidnap you so you escape unharmed?"},
#  {'doc_id': '915',
#   'text': "How do you stop a criminal's attempt to kidnap you and escape unharmed?"},
#  {'doc_id': '916', 'text': 'How do I sell on Amazon?'},
#  {'doc_id': '917', 'text': 'How do I start selling on Amazon?'},
#  {'doc_id': '918', 'text': 'Daniel Ek: When an we expect Spotify in India?'},
#  {'doc_id': '919',
#   'text': 'Daniel Ek: Are there any future plans of releasing Spotify in India?'},
#  {'doc_id': '920',
#   'text': 'What are the top 10 books one should read in his or her early 20s?'},
#  {'doc_id': '921', 'text': 'What books are worth reading in early 20s?'},
#  {'doc_id': '922',
#   'text': 'Which book should I start with for the GATE preparation?'},
#  {'doc_id': '923', 'text': 'What book do I start with for GATE preparation?'},
#  {'doc_id': '924',
#   'text': 'What does the phrase "He who does not love abides in death" exactly mean?'},
#  {'doc_id': '925', 'text': 'What does the phrase "love begets love" mean?'},
#  {'doc_id': '926', 'text': 'What is similar to 4Shared?'},
#  {'doc_id': '927', 'text': 'What is similar to 4shared but better?'},
#  {'doc_id': '928',
#   'text': 'Can you get high if someone touches weed and then you shake their hand and then you eat something with that same hand?'},
#  {'doc_id': '929',
#   'text': 'If someone grabs you by your shirt with both their hands and tells you to shut up, is that assault and can you call the police?'},
#  {'doc_id': '930',
#   'text': 'Considering the current trend of information technology what is the future of print media?'},
#  {'doc_id': '931', 'text': "What is this model's name? I see her everywhere."},
#  {'doc_id': '932', 'text': 'What is the best recipe for chicken pizza?'},
#  {'doc_id': '933', 'text': 'What are some good pizza recipes?'},
#  {'doc_id': '934',
#   'text': 'What are some good places to learn mountaineering in India?'},
#  {'doc_id': '935',
#   'text': 'What are some good mountaineering institutes for a beginner level mountaineering course?'},
#  {'doc_id': '936', 'text': 'Do new table tennis balls damage rubbers?'},
#  {'doc_id': '937', 'text': 'How do you unlock a car with a tennis ball?'},
#  {'doc_id': '938',
#   'text': "My new Xbox one S can't connect to internet during setup. Any solutions?"},
#  {'doc_id': '939',
#   'text': 'Can I withdraw my money from any branch of particular bank .my bank is bank of Baroda I have no Atm card and cheque book?'},
#  {'doc_id': '940', 'text': 'Is it wrong for me to be content with my life?'},
#  {'doc_id': '941', 'text': 'What is a cover story?'},
#  {'doc_id': '942', 'text': 'Is gravity only a theory?'},
#  {'doc_id': '943',
#   'text': 'According to the M-theory, there are 11 dimensions. Why are only 5 dimensions in regards to gravity addressed in Interstellar?'},
#  {'doc_id': '944',
#   'text': 'How could I become a fighter pilot when I have less than the required eyesight?'},
#  {'doc_id': '945',
#   'text': 'I have terrible eyesight. Can I still become a fighter pilot in the Air Force?'},
#  {'doc_id': '946', 'text': 'Operation executive salary in Infosys?'},
#  {'doc_id': '947',
#   'text': 'How do I do the Wake Back To Bed lucid dreaming technique when I think I have restless leg syndrome (regardless, my legs hurt at night.)?'},
#  {'doc_id': '948', 'text': 'Have cavemen been scientifically tested?'},
#  {'doc_id': '949',
#   'text': 'Have mythical creatures been scientifically tested?'},
#  {'doc_id': '950', 'text': 'Can climate change be reversed?'},
#  {'doc_id': '951',
#   'text': 'Can the global climate change be reversed or halted?'},
#  {'doc_id': '952', 'text': 'How should ask my crush for her number?'},
#  {'doc_id': '953', 'text': 'What should I ask my crush?'},
#  {'doc_id': '954', 'text': 'Why do I believe that gravitation force exist?'},
#  {'doc_id': '955', 'text': 'Does gravitational force exists in all planets?'},
#  {'doc_id': '956', 'text': 'Did Mahabharata really happen?'},
#  {'doc_id': '957',
#   'text': 'Did Mahabharata really happen or only an allegory according to M.K.Gandhi?'},
#  {'doc_id': '958',
#   'text': 'Can Congress stop Presidents from starting a major war?'},
#  {'doc_id': '959',
#   'text': "What's a good source to purchase Attorneys eMail addresses? Thanks"},
#  {'doc_id': '960', 'text': 'Is it safe to lose 25 pounds in 1 month?'},
#  {'doc_id': '961', 'text': 'Is it healthy to lose 13 pounds in a month?'},
#  {'doc_id': '962', 'text': 'What are some cute shounen ai series?'},
#  {'doc_id': '963', 'text': 'When will the Pokémon series end?'},
#  {'doc_id': '964', 'text': 'Why are police lights red and blue?'},
#  {'doc_id': '966',
#   'text': 'How do I post a question that was marked as needing improvement?'},
#  {'doc_id': '967',
#   'text': 'Why was my question marked as "needs improvement?"'},
#  {'doc_id': '968', 'text': 'Who owns nature?'},
#  {'doc_id': '969', 'text': 'Who owns Natural Factors?'},
#  {'doc_id': '970', 'text': 'How can I install OBB/data file on an Android?'},
#  {'doc_id': '971',
#   'text': 'I want to install EXE extension files in Android mobile. Is it possible?'},
#  {'doc_id': '972',
#   'text': 'What is garbage value? And Why do we get garbage value in c?'},
#  {'doc_id': '973', 'text': 'What is garbage value in c?'},
#  {'doc_id': '974', 'text': 'How do I prepare for software interviews?'},
#  {'doc_id': '976',
#   'text': 'Does Rahul Gandhi have any chance to become next PM of India after Modi?'},
#  {'doc_id': '977',
#   'text': 'Does Rahul Gandhi have chances to become next Pm of India after Modi?'},
#  {'doc_id': '978', 'text': 'Is noon 12 am or 12 pm?'},
#  {'doc_id': '979',
#   'text': 'Is it good to do gym at morning and swimming at noon?'},
#  {'doc_id': '980',
#   'text': 'What is the difference between a comet and an asteroid?'},
#  {'doc_id': '981',
#   'text': 'What is the difference between asteroids and comets?'},
#  {'doc_id': '982', 'text': 'Is chocolate milk good for you?'},
#  {'doc_id': '983', 'text': 'Why is unrefrigerated milk good for you?'},
#  {'doc_id': '984', 'text': 'How should I study'},
#  {'doc_id': '985', 'text': 'What are some tricks to study effectively?'},
#  {'doc_id': '986',
#   'text': 'Which country is best for higher education and work?'},
#  {'doc_id': '987',
#   'text': 'Which is the best country for higher education after USA and UK?'},
#  {'doc_id': '988', 'text': 'What is the painting on this image?'},
#  {'doc_id': '989', 'text': 'What is this painting?'},
#  {'doc_id': '990',
#   'text': 'Which are the major highways in California and how are they compared to the major highways in Tennessee?'},
#  {'doc_id': '991',
#   'text': 'Which are the major highways in California and how are they compared to the major highways in Texas?'},
#  {'doc_id': '992', 'text': "What's beyond our Universe?"},
#  {'doc_id': '993',
#   'text': 'If space is expanding, where does the new space come from?'},
#  {'doc_id': '994',
#   'text': 'Is growing of hair a physical or a chemical change?'},
#  {'doc_id': '995', 'text': 'Can a bald person ever grow their hair back?'},
#  {'doc_id': '996',
#   'text': 'What is the difference between culture and history?'},
#  {'doc_id': '997', 'text': 'How is chili different between cultures?'},
#  {'doc_id': '998', 'text': 'What does it mean when a guy says I like you?'},
#  {'doc_id': '999', 'text': 'What does it mean when a guy says "Be safe"?'},
#  {'doc_id': '1000', 'text': 'What makes a programmer "good?"'},
#  {'doc_id': '1001', 'text': 'What makes a good programmer great?'},
#  {'doc_id': '1002', 'text': 'What will most likely cause World War III?'},
#  {'doc_id': '1003', 'text': 'Is World War III imminent?'},
#  {'doc_id': '1004',
#   'text': 'Is civil war likely after the US presidential election?'},
#  {'doc_id': '1005',
#   'text': 'Is the US at risk of some type of uprising after the election?'},
#  {'doc_id': '1006',
#   'text': 'Which European country is the best for asylum seekers?'},
#  {'doc_id': '1007',
#   'text': 'What are the best countries for whistleblowers to seek asylum?'},
#  {'doc_id': '1008',
#   'text': 'Where and how do the crop circles get generated?'},
#  {'doc_id': '1009', 'text': 'What are crop circles?'},
#  {'doc_id': '1010', 'text': 'Will baking soda help pass a urine test?'},
#  {'doc_id': '1011', 'text': 'How does baking soda help you pass a drug test?'},
#  {'doc_id': '1012', 'text': 'What is Zika virus and how is it transmitted?'},
#  {'doc_id': '1013', 'text': 'How is Zika virus spread?'},
#  {'doc_id': '1014',
#   'text': 'What is the best way to learn algebra by yourself?'},
#  {'doc_id': '1015', 'text': 'How do you learn algebra 1 fast?'},
#  {'doc_id': '1016', 'text': 'How does it feel to retake a class in college?'},
#  {'doc_id': '1017',
#   'text': 'Does retaking subjects in college affect future job prospects?'},
#  {'doc_id': '1018',
#   'text': 'Does Google Display Network require any site to have it SEO (on-page and off-page optimized) first before they can proceed with GDN? Is this possible?'},
#  {'doc_id': '1019',
#   'text': 'How can I get my name off the first page on Google search?'},
#  {'doc_id': '1020',
#   'text': 'How hard is it to fake appearing "spiritual" in a Christian community?'},
#  {'doc_id': '1021',
#   'text': 'Why did the Battle of Agincourt happen? How does it compare to the Battle of Edge Hill?'},
#  {'doc_id': '1022', 'text': 'What is an actinomorphic flower?'},
#  {'doc_id': '1023', 'text': 'Flowers: What is vaijanti?'},
#  {'doc_id': '1024', 'text': 'What is the best place for sex?'},
#  {'doc_id': '1025', 'text': 'What is the best place to have sex from?'},
#  {'doc_id': '1026', 'text': 'Do people with anemia die younger?'},
#  {'doc_id': '1027', 'text': 'Does anemia increase irritability?'},
#  {'doc_id': '1028',
#   'text': 'How do you feel about the new MacBook Pro, late 2016?'},
#  {'doc_id': '1029', 'text': 'Should I get the new Macbook Pro?'},
#  {'doc_id': '1030',
#   'text': 'Does covering your head while sleeping cause brain damage?'},
#  {'doc_id': '1031',
#   'text': 'Does binge drinking cause long term brain damage?'},
#  ...]

# %%
from tqdm import tqdm

for doc in tqdm(docs, desc="Indexing documents"):
    embedding = get_embedding(doc["text"])

    # Index ke Elasticsearch
    es.index(
        index=index_name,
        id=doc["doc_id"],
        document={
            "doc_id": doc["doc_id"],
            "text": doc["text"],
            "embedding": embedding.tolist()
        }
    )
# Out:
# Indexing documents: 100%|██████████| 10000/10000 [10:40<00:00, 15.60it/s]

# %%
query_text = "bitcoin"
query_embedding = get_embedding(query_text)

query = {
    "size": 5,
    "query": {
        "script_score": {
            "query": {
                "match": {
                    "text": query_text
                }
            },
            "script": {
                "source": "cosineSimilarity(params.query_vector, 'embedding') + _score",
                "params": {
                    "query_vector": query_embedding.tolist()  # Vector query dalam bentuk list
                }
            }
        }
    }
}

response = es.search(index=index_name, body=query)

for hit in response["hits"]["hits"]:
    doc_id = hit["_source"]["doc_id"]
    score = hit["_score"]
    text = hit["_source"]["text"]
    print(f"Doc ID: {doc_id}\nScore: {score}\nText: {text}\n{'-'*50}")
# Out:
# Doc ID: 8044
# Score: 9.793897
# Text: How can Bitcoin be hacked?
# --------------------------------------------------
# Doc ID: 8045
# Score: 8.89599
# Text: Is Bitcoin mining still profitable in 2016?
# --------------------------------------------------
# Doc ID: 4733
# Score: 7.923117
# Text: What is an intuitive explanation of how bitcoin mining works?
# --------------------------------------------------
# Doc ID: 715
# Score: 7.5339375
# Text: Could all bitcoin mining be done by a single Raspberry Pi?
# --------------------------------------------------
# Doc ID: 1822
# Score: 7.3731337
# Text: What is the risk of selling bitcoin and accepting credit card payment?
# --------------------------------------------------
